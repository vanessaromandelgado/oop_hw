# %% [markdown]
# ### Object Oriented Programming Weekend Assignment <br>
# <p>Calculate the Return on Investment (ROI) for a rental property.</p>
# <a href="https://docs.google.com/document/d/1EU_E9gcBOgQJm7p4sUyQZZIQ3CCyWSTXitICF6k9f_0/edit?usp=sharing">My Notes</a>

# %%
class ReturnOnIncome:
    def __init__(self):
        pass
    def rental_income(self, rental_income):
        rental_income = input ('What is your monthly rental income? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly rental income is ${rental_income} dollars.")
        pass
    def laundry_income(self, laundry_income):
        laundry_income = input ('What is your monthly laundry income? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly laundry income is ${laundry_income} dollars.")
        pass
    def storage_income(self,storage_income):
        storage_income = input ('What is your monthly storage income? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly laundry income is ${storage_income} dollars.")
        pass
    def misc_income(self, misc_income):
        misc_income = input ('What is your monthly miscellaneious income? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly miscellaneious income is ${misc_income} dollars.")
        pass
    def total_monthly_income(self, total_monthly_income):
        total_monthly_income = sum(int(rental_income, laundry_income, storage_income, misc_income))
        return (f'Your total monthly income is ${total_monthly_income} dollars.')
        pass
class Expenses():    
    def __init__(self):
        pass
    def taxes(self, taxes):
        taxes= input ('What is your monthly tax percent? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly expenses on taxes is ${taxes} dollars.")
        pass    
    def insurance(self, insurance):
        insurance= input ('What is your monthly insurance cost? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly insurance cost is ${insurance} dollars.")
        pass
    def water_sewer(self,water_sewer):
        water_sewer = input ('What is your monthly water and sewer cost? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly water and sewer cost is ${water_sewer} dollars.")
        pass
    def garbage(self, garbage):
        garbage= input ('What is your monthly garagage cost? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly garabage expense is ${garabage} dollars.")
        pass
    def electric(self, electric):
        electric= input ('What is your monthly garagage cost? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly electric expense is ${electric} dollars.")
        pass
    def gas(self, gas):
        gas= input ('What is your monthly gas expense? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly garabage expense is ${garabage} dollars.")
        pass
    def hoa_fees(self, hoa_fees):
        hoa_fees= input ('What is your monthly HOA fees? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly HOA cost is ${hoa_fees} dollars.")
        pass
    def lawn_snow(self, lawn_snow):
        lawn_snow= input ('What is your monthly cost to maintain lawn or snow? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly lawn or snow cost is ${lawn_snow} dollars.")
        pass
    def vacancy(self, vacancy):
        vacancy= input ('What is your monthly vacancy cost? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly vacancy cost is ${vacancy} dollars.")
        pass
    def repairs(self, repairs):
        repairs= input ('What is your monthly repairs cost? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly reapairs cost is ${repairs} dollars.")
        pass  
    def cap_exp(self, cap_exp):
        cap_exp= input ('What is your monthly capital expenditure? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly capital expenditurs are ${cap_exp} dollars.")
        pass
    def prop_man(self, prop_man):
        prop_man= input ('What are your property management fees? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly property management fees are ${prop_man} dollars.")
        pass
    def mortgage(self, mortgage):
        mortgage= input ('What is your monthly mortgage cost? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your monthly mortgage epenses are ${mortgage} dollars.")
        pass    
class CashFlow:
    def __init__(self):
        pass
    def total_monthly_cashflow(self, total_monthly_cashflow):
        total_monthly_cashflow = int({total_monthly_income} - {total_monthly_expenses})
        print(f"Your total monthly cash flow is ${total_monthly_cashflow} dollars.")
    def total_annual_cashflow(self, total_annual_cashflow):
        total_annual_cashflow = 12 * ({total_monthly_cashflow})
        print (f"Your annual cash flow is ${total_annual_cashflow} dollars.")
        pass
class CashOnCashReturns:
    def __init__(self):
        pass
    def down_payment(self,down_payment):
        down_payment = input ('What is your annual down payment fee? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your annual down payment is ${down_payment} dollars.")
        pass
    def closing_costs(self, misc_income):
        closing_costs = input ('What are your annual closing costs? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your annual closing costs are ${closing_costs} dollars.")
        pass
    def rehab_budget(self, total_monthly_income):
        rehab_budget = input ('What are your annual rehabilitation budget? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your annual rehabilitation costs are ${rehab_cost} dollars.")
        pass
    def misc(self, misc):
        misc = input ('What are any annual miscellaneous fees? Please enter only whole numbers, not commas, nor decimals.')
        print (f"Your annual miscellaneous fees are ${misc} dollars.")
        pass
    def total_investment(self, total_investment):
        total_investment = sum(int({down_payment},{closing_costs},{rehab_budget},{misc}))
        print(f"Your total investment is ${total_investment} dollars.")
    def cash_on_cash_return(self, total_annual_cashflow):
        cash_on_cash_return = 100 * ({total_annual_cashflow} // {total_investment})
        print (f"Your annual cash on cash return, in other words, the percentage yield return on your cash investment is ${cash_on_cash_return} dollars.")
        pass

# %%
"""creating instance of ROI calculator"""

my_calculator = ReturnOnIncome()


"""creating function to run the returnOnIncome(my_calculator) mehtods"""

def run ():
    while True:
        response = input("Please enter how you'd like to continue using this ROI calculator by typing in begin or quit.")

        if response.lower() == 'quit':
            print('Thanks for trying out this ROI calculator.')
            break
        elif response.lower() == "begin":
            my_calculator.rental_income(f"")
            my_calculator.laundry_income(f"")
            my_calculator.storage_income(f"")
            my_calculator.misc_income(f"")
            my_calculator.total_monthly_income(f"")
            my_calculator.taxes(f"")
            my_calculator.insurance(f"")
            my_calculator.water_sewer(f"")
            my_calculator.garabage(f"")
            my_calculator.electric(f"")
            my_calculator.gas(f"")
            my_calculator.hoa_fees(f"")
            my_calculator.lawn_snow(f"")
            my_calculator.vacancy(f"")
            my_calculator.repairs(f"")
            my_calculator.capex(f"")
            my_calculator.prop_man(f"")
            my_calculator.mortgage(f"")
            my_calculator.total_monthly_expenses(f"")
            my_calculator.down_payment(f"")
            my_calculator.closing_costs(f"")
            my_calculator.rehab_budget(f"")
            my_calculator.misc(f"")
            my_calculator.total_investment(f"")
            my_calculator.cash_on_cash_return(f"")
        
run()
# Out:
# Your monthly rental income is $1 dollars.
# Thanks for trying out this ROI calculator.
